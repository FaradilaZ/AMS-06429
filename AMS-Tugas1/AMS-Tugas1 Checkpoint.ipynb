# %% [markdown]
#     ## Nama : Faradila Zahrotunnisa
#     ## Nim : A12.2020.06429
#     ## Kelp : A12.6501
#
# # Eksperimen dan Pengumpulan Dataset
#
# ## Pemanggilan Library 1

# %%
import pandas as pd
import time
import tweepy
import numpy as np

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    # Otentikasi dan akses menggunakan kunci:
    auth = tweepy.OAuthHandler("lr5lTHMv7q3c6gOeCR8w0DFzQ", "t9LpATUUcebgxKaHm0fgxjWMqXK3kZBxeL98WHEOSolf8dFLt4")
    auth.set_access_token("1576445316596781056-RXF1mToSQtHn6O9BRxbAzeaTV3zN7N", "UpmNsnkOoCxzn0lKhMas7LV0KfeKBm0QAeobWz66ohLuM")
    # Kembalikan akses ke API:
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
# buat extractor object
extractor = twitter_config()
# Out:
# Authentication OK

# %% [markdown]
# ## Ambil Tweet dari Username
#
# #### Username yang saya gunakan yakni @KompasTV

# %%
tweets = extractor.user_timeline(screen_name="KompasTV", count=1000)
print("Tweets terambil: {}.\n".format(len(tweets)))

print("100 tweet teratas:\n")
for tweet in tweets[:100]:
    print(tweet.text)
    print()
# Out:
# Tweets terambil: 200.
#
# 100 tweet teratas:
#
# Kali ini Pinkan Mambo bertamu ke #KODEKompasTV dan curhat isi hatinya kepada Wulan Juliani tentang karir, perjuanga… https://t.co/NMhK7js8GS
#
# Menteri BUMN dan Sebagai Anggota Komite Olimpiade Internasional (IOC) @erickthohir bertemu dengan Presiden Federasi… https://t.co/vRsES2vND6
#
# Menikmati Jakarta dari tiga sisi yuk, Teman Jalan! Steffy dan Marcell kali ini mau mencoba destinasi wisata yang ad… https://t.co/LL3V2kRyLx
#
# Raja Maha Vajiralongkorn dan istrinya Ratu Suthida bertemu dengan kerabat korban penembakan mantan polisi. Insiden… https://t.co/obGKv2Ba3m
#
# Salut!!! ARMY BTS Kumpulkan Donasi Rp 447 Juta Dalam 1,5 Hari Untuk Korban Tragedi Kanjuruhan… https://t.co/nmF6gPCu4Y
#
# 4 Cara Screenshot di Windows 10 Tanpa Aplikasi https://t.co/q9yI9KOsp8 https://t.co/icP7in4Gya
#
# Saksikan keseruan #SemarakSatria bersama Akademi TNI dan tentunya penampilan spesial dari Candil sesaat lagi hanya… https://t.co/BddgD4rqGo
#
# Perbarui informasi terkini dengan nonton #KompasUpdate sesaat lagi, bersama @EntrasolID #Ad #NutrisiSetiapHari https://t.co/wAdnr9HQIO
#
# Begini Cerita Aremania Yang Jadi Korban Tendangan Kungfu Aparat TNI https://t.co/HgdJPXPLD5 https://t.co/BDuvleCDrl
#
# Cerita Erick Thohir Bertemu Presiden FIFA di Qatar Bicara Terkait Tragedi Kanjuruhan https://t.co/lYC0ULTl4J https://t.co/Au2BygN7nC
#
# Menyaksikan Pelajar Kenya Menari Tradisional Indonesia dalam Resepsi Diplomatik KBRI Nairobi 2022… https://t.co/ShjNUXC9gd
# Aremania Menggelar Kirim Doa 7 Hari Korban Tragedi Kanjuruhan di Halaman Stadion Kanjuruhan https://t.co/NNaVSzINfR https://t.co/FAxHLm19hB
#
# Pesona Alam Danau Perintis Dan Sejarahnya https://t.co/FH6BGxXGWN https://t.co/LTkkDrrmPk
#
# Hoaks mengenai perubahan ASI setelah vaksin covid-19, video hoax Presiden Jokowi mengunjungi Lesti, hingga video ho… https://t.co/sVBEDIcVQJ
#
# Manajer Liverpool Jurgen Klopp: Kami Harus Bagus sampai Kami Jadi Luar Biasa https://t.co/Ha9fWF1lZp https://t.co/gUHSfYsmR2
#
# Pemerintah, FIFA dan AFC Akan Bentuk Tim Transformasi Sepak Bola Indonesia Pasca Tragedi Kanjuruhan… https://t.co/5J4WXBkIlv
#
# Dua gudang penyimpanan bahan cat di Bantul, Yogyakarta terbakar pada Jumat (7/10) malam. Tidak ada korban jiwa akib… https://t.co/quAXefFBYY
#
# Dapatkan GoPay senilai Rp 4 juta dari #KuisKompascom
#
# Sekarang, formatnya baru, poinnya lebih banyak, dan menangnya… https://t.co/NAiKEWBySC
#
# Data Korban Kanjuruhan dari Polri: 547 Orang Korban Luka-luka, 23 Orang Luka Berat https://t.co/hny9kE3ymy https://t.co/KR3RsM0kH9
#
# Kali ini Pinkan Mambo bertamu ke #KODEKompasTV dan curhat isi hatinya kepada Wulan Juliani tentang karir, perjuanga… https://t.co/GMGztyLnEg
#
# Kesibukan Ate Setelah Menjadi Juara 3 di SUCI IX | SHOW 7 SUCI X https://t.co/bRowkFuRai https://t.co/mbdFyzhQ9Q
#
# Sejumlah Perjalanan Kereta Api Terlambat akibat Penurunan Tanah, Ini Daftarnya https://t.co/ZV3Krbg9Dr https://t.co/Pny2GWCxLc
#
# Jelang Big Match Arsenal vs Liverpool, Mikel Arteta: Pertandingan yang Sangat Menuntut https://t.co/qYsiXSy9Cs https://t.co/S9mIrZ2obU
#
# Ribuan Warga Aceh Utara Mengungsi Akibat Banjir, Bantuan Akan Segera Didistribusikan https://t.co/AdsgXjRPvw https://t.co/8CUQBSVPHs
#
# Tim #JalanMakan masih kasih info liburan dari Cilegon nih guys! Kali ini kita mau kasih tahu wahana main air yang r… https://t.co/Q6LOXEnI91

# %% [markdown]
# ## Memasukkan ke dataframe pandas

# %%
# Membuat kerangka data menggunakan sintaks berikut
dataset = pd.DataFrame(data = [tweet.text for tweet in tweets], columns = ['Tweets'])

# Tampilan kerangka data
display(dataset.head(100))
# Out:
#                                                Tweets
# 0   Kali ini Pinkan Mambo bertamu ke #KODEKompasTV...
# 1   Menteri BUMN dan Sebagai Anggota Komite Olimpi...
# 2   Menikmati Jakarta dari tiga sisi yuk, Teman Ja...
# 3   Raja Maha Vajiralongkorn dan istrinya Ratu Sut...
# 4   Salut!!! ARMY BTS Kumpulkan Donasi Rp 447 Juta...
# ..                                                ...
# 95  Kesibukan Ate Setelah Menjadi Juara 3 di SUCI ...
# 96  Sejumlah Perjalanan Kereta Api Terlambat akiba...
# 97  Jelang Big Match Arsenal vs Liverpool, Mikel A...
# 98  Ribuan Warga Aceh Utara Mengungsi Akibat Banji...
# 99  Tim #JalanMakan masih kasih info liburan dari ...
#
# [100 rows x 1 columns]

# %%
dataset.to_csv('dataset_KompasTV.csv')

# %% [markdown]
# ## Cleaning Word
#
# ## Import Library untuk Cleaning Word

# %%
import pandas as pd
import re
import string
import time
from copy import deepcopy

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('dataset_KompasTV.csv')

df.head(10)
# Out:
#    Unnamed: 0                                             Tweets
# 0           0  Kali ini Pinkan Mambo bertamu ke #KODEKompasTV...
# 1           1  Menteri BUMN dan Sebagai Anggota Komite Olimpi...
# 2           2  Menikmati Jakarta dari tiga sisi yuk, Teman Ja...
# 3           3  Raja Maha Vajiralongkorn dan istrinya Ratu Sut...
# 4           4  Salut!!! ARMY BTS Kumpulkan Donasi Rp 447 Juta...
# 5           5  4 Cara Screenshot di Windows 10 Tanpa Aplikasi...
# 6           6  Saksikan keseruan #SemarakSatria bersama Akade...
# 7           7  Perbarui informasi terkini dengan nonton #Komp...
# 8           8  Begini Cerita Aremania Yang Jadi Korban Tendan...
# 9           9  Cerita Erick Thohir Bertemu Presiden FIFA di Q...

# %%
df
# Out:
#      Unnamed: 0                                             Tweets
# 0             0  Kali ini Pinkan Mambo bertamu ke #KODEKompasTV...
# 1             1  Menteri BUMN dan Sebagai Anggota Komite Olimpi...
# 2             2  Menikmati Jakarta dari tiga sisi yuk, Teman Ja...
# 3             3  Raja Maha Vajiralongkorn dan istrinya Ratu Sut...
# 4             4  Salut!!! ARMY BTS Kumpulkan Donasi Rp 447 Juta...
# ..          ...                                                ...
# 195         195  Ketua Panpel Arema FC: Saya Sudah Ingatkan Pen...
# 196         196  Seratus Makanan Khas Jambi di Perkenalkan http...
# 197         197  Banjir Rendam 12 Kecamatan di Aceh Utara, 31 R...
# 198         198  Anies Baswedan Temui Ketum Partai Demokrat AHY...
# 199         199  Polisi Otopsi Jenazah Tobri https://t.co/jQp58...
#
# [200 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   Tweets      200 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# # Preprocessing Dataset
#
# Yang harus dilakukan yaitu instalasi modul ekphrasis

# %%
# !pip install ekphrasis
# Out:
# Collecting ekphrasis
#   Downloading ekphrasis-0.5.4-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: ujson in ./opt/anaconda3/lib/python3.9/site-packages (from ekphrasis) (5.1.0)
# Requirement already satisfied: matplotlib in ./opt/anaconda3/lib/python3.9/site-packages (from ekphrasis) (3.5.1)
# Collecting termcolor
#   Downloading termcolor-2.0.1-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: tqdm in ./opt/anaconda3/lib/python3.9/site-packages (from ekphrasis) (4.64.0)
# Requirement already satisfied: numpy in ./opt/anaconda3/lib/python3.9/site-packages (from ekphrasis) (1.21.5)
# Requirement already satisfied: nltk in ./opt/anaconda3/lib/python3.9/site-packages (from ekphrasis) (3.7)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 3.4 MB/s eta 0:00:011
# Requirement already satisfied: colorama in ./opt/anaconda3/lib/python3.9/site-packages (from ekphrasis) (0.4.4)
# Requirement already satisfied: wcwidth>=0.2.5 in ./opt/anaconda3/lib/python3.9/site-packages (from ftfy->ekphrasis) (0.2.5)
# Requirement already satisfied: packaging>=20.0 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib->ekphrasis) (21.3)
# Requirement already satisfied: cycler>=0.10 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib->ekphrasis) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib->ekphrasis) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib->ekphrasis) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib->ekphrasis) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib->ekphrasis) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib->ekphrasis) (1.3.2)
# Requirement already satisfied: six>=1.5 in ./opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# Requirement already satisfied: regex>=2021.8.3 in ./opt/anaconda3/lib/python3.9/site-packages (from nltk->ekphrasis) (2022.3.15)
# Requirement already satisfied: joblib in ./opt/anaconda3/lib/python3.9/site-packages (from nltk->ekphrasis) (1.1.0)
# Requirement already satisfied: click in ./opt/anaconda3/lib/python3.9/site-packages (from nltk->ekphrasis) (8.0.4)
# Installing collected packages: termcolor, ftfy, ekphrasis
# Successfully installed ekphrasis-0.5.4 ftfy-6.1.1 termcolor-2.0.1

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# /Users/faradilazahrotunnisa/opt/anaconda3/lib/python3.9/site-packages/ekphrasis/classes/tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Word statistics files not found!
# Downloading... done!
# Unpacking... done!
# Reading twitter - 1grams ...
# generating cache file for faster loading...
# reading ngrams /Users/faradilazahrotunnisa/.ekphrasis/stats/twitter/counts_1grams.txt
# Reading twitter - 2grams ...
# generating cache file for faster loading...
# reading ngrams /Users/faradilazahrotunnisa/.ekphrasis/stats/twitter/counts_2grams.txt
# Reading twitter - 1grams ...
# /Users/faradilazahrotunnisa/opt/anaconda3/lib/python3.9/site-packages/ekphrasis/classes/exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %%
# panggil ekphrasis

def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

# %%
# fungsi dari AMS 01-03. silakan cek bagaimana saya merubah menjadi fungsi

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space(text):
    return " ".join(text.split())

def remove_emoji(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %%
# hapus untuk <>
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# ## Mulai proses pembersihan

# %%
i = 0
final_string = []
s = ""
for text in df['Tweets'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

# %%
df.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0  Kali ini Pinkan Mambo bertamu ke #KODEKompasTV...
# 1           1  Menteri BUMN dan Sebagai Anggota Komite Olimpi...
# 2           2  Menikmati Jakarta dari tiga sisi yuk, Teman Ja...
# 3           3  Raja Maha Vajiralongkorn dan istrinya Ratu Sut...
# 4           4  Salut!!! ARMY BTS Kumpulkan Donasi Rp 447 Juta...
# 5           5  4 Cara Screenshot di Windows 10 Tanpa Aplikasi...
# 6           6  Saksikan keseruan #SemarakSatria bersama Akade...
# 7           7  Perbarui informasi terkini dengan nonton #Komp...
# 8           8  Begini Cerita Aremania Yang Jadi Korban Tendan...
# 9           9  Cerita Erick Thohir Bertemu Presiden FIFA di Q...
#
#                                               step01
# 0  kali ini pinkan mambo bertamu ke dan curhat is...
# 1  menteri bumn dan sebagai anggota komite olimpi...
# 2  menikmati jakarta dari tiga sisi yuk teman jal...
# 3  raja maha vajiralongkorn dan istrinya ratu sut...
# 4  salut army bts kumpulkan donasi rp   juta dala...
# 5    cara screenshot di windows   tanpa aplikasi ...
# 6  saksikan keseruan bersama akademi tni dan tent...
# 7  perbarui informasi terkini dengan nonton sesaa...
# 8  begini cerita aremania yang jadi korban tendan...
# 9  cerita erick thohir bertemu presiden fifa di q...

# %% [markdown]
# ## Hapus Data Kosong

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   Tweets      200 non-null    object
#  2   step01      200 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.8+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      int64
#  1   Tweets      0 non-null      object
#  2   step01      0 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 0.0+ bytes

# %%
df_hapus.head(10)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Tweets, step01]
# Index: []

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   Tweets      200 non-null    object
#  2   step01      200 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.8+ KB

# %%
df_new
# Out:
#      Unnamed: 0                                             Tweets  \
# 0             0  Kali ini Pinkan Mambo bertamu ke #KODEKompasTV...
# 1             1  Menteri BUMN dan Sebagai Anggota Komite Olimpi...
# 2             2  Menikmati Jakarta dari tiga sisi yuk, Teman Ja...
# 3             3  Raja Maha Vajiralongkorn dan istrinya Ratu Sut...
# 4             4  Salut!!! ARMY BTS Kumpulkan Donasi Rp 447 Juta...
# ..          ...                                                ...
# 195         195  Ketua Panpel Arema FC: Saya Sudah Ingatkan Pen...
# 196         196  Seratus Makanan Khas Jambi di Perkenalkan http...
# 197         197  Banjir Rendam 12 Kecamatan di Aceh Utara, 31 R...
# 198         198  Anies Baswedan Temui Ketum Partai Demokrat AHY...
# 199         199  Polisi Otopsi Jenazah Tobri https://t.co/jQp58...
#
#                                                 step01
# 0    kali ini pinkan mambo bertamu ke dan curhat is...
# 1    menteri bumn dan sebagai anggota komite olimpi...
# 2    menikmati jakarta dari tiga sisi yuk teman jal...
# 3    raja maha vajiralongkorn dan istrinya ratu sut...
# 4    salut army bts kumpulkan donasi rp   juta dala...
# ..                                                 ...
# 195  ketua panpel arema fc saya sudah ingatkan peng...
# 196  seratus makanan khas jambi di perkenalkan cotr...
# 197  banjir rendam   kecamatan di aceh utara   ribu...
# 198  anies baswedan temui ketum partai demokrat ahy...
# 199   polisi otopsi jenazah tobri cojqpicge coessnkrzt
#
# [200 rows x 3 columns]

# %% [markdown]
# ## Normalisasi kata slang menjadi baku

# %%
# token
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/faradilazahrotunnisa/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df["step01"].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0  Kali ini Pinkan Mambo bertamu ke #KODEKompasTV...
# 1           1  Menteri BUMN dan Sebagai Anggota Komite Olimpi...
# 2           2  Menikmati Jakarta dari tiga sisi yuk, Teman Ja...
# 3           3  Raja Maha Vajiralongkorn dan istrinya Ratu Sut...
# 4           4  Salut!!! ARMY BTS Kumpulkan Donasi Rp 447 Juta...
# 5           5  4 Cara Screenshot di Windows 10 Tanpa Aplikasi...
# 6           6  Saksikan keseruan #SemarakSatria bersama Akade...
# 7           7  Perbarui informasi terkini dengan nonton #Komp...
# 8           8  Begini Cerita Aremania Yang Jadi Korban Tendan...
# 9           9  Cerita Erick Thohir Bertemu Presiden FIFA di Q...
#
#                                               step01  \
# 0  kali ini pinkan mambo bertamu ke dan curhat is...
# 1  menteri bumn dan sebagai anggota komite olimpi...
# 2  menikmati jakarta dari tiga sisi yuk teman jal...
# 3  raja maha vajiralongkorn dan istrinya ratu sut...
# 4  salut army bts kumpulkan donasi rp   juta dala...
# 5    cara screenshot di windows   tanpa aplikasi ...
# 6  saksikan keseruan bersama akademi tni dan tent...
# 7  perbarui informasi terkini dengan nonton sesaa...
# 8  begini cerita aremania yang jadi korban tendan...
# 9  cerita erick thohir bertemu presiden fifa di q...
#
#                                               tokens
# 0  [kali, ini, pinkan, mambo, bertamu, ke, dan, c...
# 1  [menteri, bumn, dan, sebagai, anggota, komite,...
# 2  [menikmati, jakarta, dari, tiga, sisi, yuk, te...
# 3  [raja, maha, vajiralongkorn, dan, istrinya, ra...
# 4  [salut, army, bts, kumpulkan, donasi, rp, juta...
# 5  [cara, screenshot, di, windows, tanpa, aplikas...
# 6  [saksikan, keseruan, bersama, akademi, tni, da...
# 7  [perbarui, informasi, terkini, dengan, nonton,...
# 8  [begini, cerita, aremania, yang, jadi, korban,...
# 9  [cerita, erick, thohir, bertemu, presiden, fif...

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0  Kali ini Pinkan Mambo bertamu ke #KODEKompasTV...
# 1           1  Menteri BUMN dan Sebagai Anggota Komite Olimpi...
# 2           2  Menikmati Jakarta dari tiga sisi yuk, Teman Ja...
# 3           3  Raja Maha Vajiralongkorn dan istrinya Ratu Sut...
# 4           4  Salut!!! ARMY BTS Kumpulkan Donasi Rp 447 Juta...
# 5           5  4 Cara Screenshot di Windows 10 Tanpa Aplikasi...
# 6           6  Saksikan keseruan #SemarakSatria bersama Akade...
# 7           7  Perbarui informasi terkini dengan nonton #Komp...
# 8           8  Begini Cerita Aremania Yang Jadi Korban Tendan...
# 9           9  Cerita Erick Thohir Bertemu Presiden FIFA di Q...
#
#                                               step01  \
# 0  kali ini pinkan mambo bertamu ke dan curhat is...
# 1  menteri bumn dan sebagai anggota komite olimpi...
# 2  menikmati jakarta dari tiga sisi yuk teman jal...
# 3  raja maha vajiralongkorn dan istrinya ratu sut...
# 4  salut army bts kumpulkan donasi rp   juta dala...
# 5    cara screenshot di windows   tanpa aplikasi ...
# 6  saksikan keseruan bersama akademi tni dan tent...
# 7  perbarui informasi terkini dengan nonton sesaa...
# 8  begini cerita aremania yang jadi korban tendan...
# 9  cerita erick thohir bertemu presiden fifa di q...
#
#                                               tokens  \
# 0  [kali, ini, pinkan, mambo, bertamu, ke, dan, c...
# 1  [menteri, bumn, dan, sebagai, anggota, komite,...
# 2  [menikmati, jakarta, dari, tiga, sisi, yuk, te...
# 3  [raja, maha, vajiralongkorn, dan, istrinya, ra...
# 4  [salut, army, bts, kumpulkan, donasi, rp, juta...
# 5  [cara, screenshot, di, windows, tanpa, aplikas...
# 6  [saksikan, keseruan, bersama, akademi, tni, da...
# 7  [perbarui, informasi, terkini, dengan, nonton,...
# 8  [begini, cerita, aremania, yang, jadi, korban,...
# 9  [cerita, erick, thohir, bertemu, presiden, fif...
#
#                                         final_tokens  \
# 0  [kali, ini, pinkan, mambo, bertamu, ke, dan, c...
# 1  [menteri, bumn, dan, sebagai, anggota, komite,...
# 2  [menikmati, jakarta, dari, tiga, sisi, yuk, te...
# 3  [raja, maha, vajiralongkorn, dan, istrinya, ra...
# 4  [salut, army, bts, kumpulkan, donasi, rp, juta...
# 5  [cara, screenshot, di, windows, tanpa, aplikas...
# 6  [saksikan, keseruan, bersama, akademi, tni, da...
# 7  [perbarui, informasi, terkini, dengan, nonton,...
# 8  [begini, cerita, aremania, yang, jadi, korban,...
# 9  [cerita, erick, thohir, bertemu, presiden, fif...
#
#                                               step02
# 0  kali ini pinkan mambo bertamu ke dan curhat is...
# 1  menteri bumn dan sebagai anggota komite olimpi...
# 2  menikmati jakarta dari tiga sisi yuk teman jal...
# 3  raja maha vajiralongkorn dan istrinya ratu sut...
# 4  salut army bts kumpulkan donasi rp juta dalam ...
# 5  cara screenshot di windows tanpa aplikasi coqy...
# 6  saksikan keseruan bersama akademi tni dan tent...
# 7  perbarui informasi terkini dengan nonton sesaa...
# 8  begini cerita aremania yang jadi korban tendan...
# 9  cerita erick thohir bertemu presiden fifa di q...

# %% [markdown]
# ## Simpan clean dataset

# %%
df_new.to_csv('clean_dataset_KompasTV')
